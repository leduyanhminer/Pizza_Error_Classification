# %%
import matplotlib.pyplot as plt 
import pandas as pd

# %%
df = pd.read_csv('pizza_data_final.csv')
df.tail()
# Out:
# C:\Users\DuyAnh\AppData\Local\Temp\ipykernel_16680\294823688.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('pizza_data_final.csv')
#                                                image_url store    oven  \
# 81546  https://oven-bucket.pizza4ps.io/images/2023071...   LTT  LTT-01
# 81547  https://oven-bucket.pizza4ps.io/images/2023071...   PHP  PHP-01
# 81548  https://oven-bucket.pizza4ps.io/images/2023071...   LTT  LTT-01
# 81549  https://oven-bucket.pizza4ps.io/images/2023071...   LTT  LTT-01
# 81550  https://oven-bucket.pizza4ps.io/images/2023071...   LTT  LTT-01
#
#       exception               created_at               updated_at  __v  \
# 81546       NaN  2023-07-11 07:15:30.195  2023-07-11 07:15:35.346    0
# 81547       NaN  2023-07-11 07:15:32.699  2023-07-11 07:15:37.566    0
# 81548       NaN  2023-07-11 07:20:09.553  2023-07-11 07:20:13.119    0
# 81549       NaN  2023-07-11 07:21:10.071  2023-07-11 07:21:13.613    0
# 81550       NaN  2023-07-11 07:21:15.501  2023-07-11 07:21:19.697    0
#
#                                               error_list model_version  \
# 81546  {'Advanced_Edge': ['Thiếu bóng | too few balls...         1.0.0
# 81547  {'Advanced_Edge': ['Thiếu bóng | too few balls...         1.0.0
# 81548  {'Advanced_Edge': ['Thiếu bóng | too few balls...         1.0.0
# 81549  {'Fermentation_condition': ['Lên men thiếu | F...         1.0.0
# 81550  {'Advanced_Edge': ['Thiếu bóng | too few balls...         1.0.0
#
#        Bánh không tròn | Distorted shape  ...  \
# 81546                                  1  ...
# 81547                                  1  ...
# 81548                                  1  ...
# 81549                                  1  ...
# 81550                                  1  ...
#
#        Sốt trên mép | Topping - Sauce covering on the edge  \
# 81546                                                  0
# 81547                                                  0
# 81548                                                  0
# 81549                                                  0
# 81550                                                  0
#
#        Lên men thiếu | Fermentation - Lack fermentation  \
# 81546                                                 0
# 81547                                                 0
# 81548                                                 0
# 81549                                                 1
# 81550                                                 0
#
#        Quá theo viền | Topping - Too strong shaping the edge  \
# 81546                                                  0
# 81547                                                  0
# 81548                                                  0
# 81549                                                  0
# 81550                                                  0
#
#        Trộn lẫn | Topping - Bended  \
# 81546                            0
# 81547                            0
# 81548                            0
# 81549                            0
# 81550                            0
#
#        Quá tập trung | Topping - Topping too centered  \
# 81546                                               0
# 81547                                               0
# 81548                                               0
# 81549                                               0
# 81550                                               0
#
#        Topping - Không đều | Not even  \
# 81546                               0
# 81547                               0
# 81548                               0
# 81549                               0
# 81550                               0
#
#        Lên men quá nhiều | Fermentation - Over fermentation  \
# 81546                                                  0
# 81547                                                  0
# 81548                                                  0
# 81549                                                  0
# 81550                                                  0
#
#        Không hình tròn | Topping - Not circled  Bánh lớn | Size - Too big  \
# 81546                                        0                          0
# 81547                                        0                          0
# 81548                                        0                          0
# 81549                                        0                          0
# 81550                                        0                          0
#
#                              id
# 81546  64ad0192a2f5430028b154fc
# 81547  64ad0194a2f5430028b154fd
# 81548  64ad02a9a2f5430028b154fe
# 81549  64ad02e6a2f5430028b154ff
# 81550  64ad02eba2f5430028b15500
#
# [5 rows x 33 columns]

# %%
all_error_list = ['Bánh không tròn | Distorted shape',
 'Cháy | Baking - Burnt',
 'Viền k đều | Edge - Uneven',
 'Bánh bé | Size - Too small',
 'Thiếu bóng | too few balls',
 'Không đốm | Baking - Does not have leopard-spotting',
 'Màu nhạt | Baking - Pale',
 'Viền nhỏ | Edge - Too small',
 'Viền to | Edge - Too big',
 'Nở viền không đủ | edge pizza is not enough swollen',
 'Viền thấp | Edge - Too low',
 'Phô mai cao | Topping - Cheese too high * with a core*',
 'Topping - Không đúng | incorrect portioning',
 'Không cân Topping - Not even half and half',
 'Sốt trên mép | Topping - Sauce covering on the edge',
 'Lên men thiếu | Fermentation - Lack fermentation',
 'Quá theo viền | Topping - Too strong shaping the edge',
 'Trộn lẫn | Topping - Bended',
 'Quá tập trung | Topping - Topping too centered',
 'Topping - Không đều | Not even',
 'Lên men quá nhiều | Fermentation - Over fermentation',
 'Không hình tròn | Topping - Not circled',
 'Bánh lớn | Size - Too big']

# %%
fig, axes = plt.subplots(nrows = 6, ncols = 4, figsize= (20, 20))
plt.subplots_adjust(hspace=0.5, wspace=0.5)
for index, error in enumerate(all_error_list):
    row = index // 4
    col = index % 4
    ax = axes[row, col]
    df.groupby(error)['id'].count().plot(kind='bar', ax=ax)
    ax.set_title(error)
    ax.set_xlabel('')

plt.show()
